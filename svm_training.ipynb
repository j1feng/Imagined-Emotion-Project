# %%
#!pip install --user pandas
#!pip install --user numpy
#!pip install --user sklearn
#!pip install --user itertools

import csv
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.utils import shuffle
from itertools import chain

#print(df)
print(df.head())

data = [[]]
label = []

mylist = [1,2,3,4,5,8,9]
for i in mylist:
    df =pd.read_csv('rec'+str(i)+'.csv')
    for index, row in df.iterrows():
        label.append(int(row['Status']))
        data.append([row['1A1'], row['1A16'], row['1A19'],row['1A21'],row['1A24'],row['1A3'],row['1A6'],row['1A7'],row['1B15'],row['1B18'],
               row['1B21'],row['1B23'],row['1B26'],row['1B30'],row['1B7'],row['1B9'],row['1C11'],row['1C13'],row['1C15'],row['1C18'],
               row['1C20'],row['1C23'],row['1C25'],row['1D12'],row['1D20'],row['1D24'],row['1D27'],row['1D30'],row['1D32'],row['1D5'],
               row['1D7'],row['1D9'],row['1E1'],row['1E12'],row['1E14'],row['1E17'],row['1E23'],row['1E29'],row['1E3'],row['1E31'],
               row['1E6'],row['1EX3'],row['1EX5'],row['1F10'],row['1F14'],row['1F21'],row['1F23'],row['1F28'],row['1F3'],
               row['1F31'],row['1F7'],row['1G11'],row['1G13'],row['1G16'],row['1G23'],row['1G25'],row['1G30'],row['1G32'],row['1G8'],
               row['1H16'],row['1H19'],row['1H2'],row['1H6'],row['1H9']])

#number of unique labels
print("number of unique labels "+str(len(set(list(label)))))
print("number of data "+str(len(label)))
data.remove([])

label, data = shuffle(label,data, random_state=0)
#print(label)

# partition
testing_data = data[:int(len(data)/4)]
training_data = data[int(len(data)/4):]

# partition
testing_label = label[:int(len(data)/4)]
training_label = label[int(len(label)/4):]

print("length of testing "+str(len(testing_data)))
print("length of training "+str(len(training_data)))

print('start training...')

clf = svm.SVC(kernel='linear', class_weight='balanced', C=1.0, random_state=0,decision_function_shape='ovo')
clf.fit(training_data, training_label)
tmp = clf.predict(testing_data)
tmp = np.split(tmp,len(tmp),0)
result = []
for i in range(len(tmp)):
    result.append(tmp[i][0])

#print(testing_label)
#print(result)

acc = 0
for i in range(len(testing_label)):
    if testing_label[i] == result[i]:
        acc+=1

print('number of correct predction:' + str(acc))
print('accuracy '+str(acc/len(testing_label)))
# Out:
#    Unnamed: 0           1A1          1A16          1A19         1A21  \
# 0           0 -27201.715364 -29315.367709 -23736.378017 -8613.312211
# 1           1 -27198.465370 -29312.836463 -23746.252999 -8607.593471
# 2           2 -27225.121571 -29338.742665 -23764.127966 -8650.780891
# 3           3 -27232.465307 -29343.648906 -23760.752972 -8657.749629
# 4           4 -27213.215343 -29324.242692 -23744.628002 -8634.374672
#
#            1A24           1A3           1A6           1A7          1B15  ...  \
# 0 -37266.728016 -35991.980372 -24534.095293 -26776.528650 -41875.125751  ...
# 1 -37264.790520 -35990.949124 -24543.595276 -26786.716131 -41876.625748  ...
# 2 -37294.727965 -36016.199077 -24568.501480 -26808.934840 -41902.281951  ...
# 3 -37293.415467 -36022.167816 -24570.501476 -26808.091091 -41905.094446  ...
# 4 -37276.259249 -36003.386601 -24549.595264 -26788.747377 -41883.469486  ...
#
#            1G25          1G30          1G32           1G8          1H16  \
# 0 -20325.321820 -28181.057304 -30111.491237 -25250.000220 -36561.291820
# 1 -20327.728065 -28180.713555 -30111.647487 -25250.281470 -36557.541827
# 2 -20355.446764 -28204.338511 -30134.178696 -25272.062680 -36585.416775
# 3 -20361.540503 -28208.869753 -30137.991189 -25275.875172 -36588.760519
# 4 -20347.071780 -28192.807283 -30120.428721 -25261.531449 -36565.135563
#
#            1H19           1H2           1H6           1H9  Status
# 0 -38695.287877 -10714.933327 -26763.591174 -31165.239290      30
# 1 -38694.256629 -10716.558324 -26766.997417 -31169.145533      30
# 2 -38721.944078 -10743.683274 -26795.841114 -31190.051745      30
# 3 -38724.881572 -10745.308271 -26799.184858 -31183.333007      30
# 4 -38702.037864 -10720.870816 -26775.247402 -31162.083046      30
#
# [5 rows x 66 columns]
# number of unique labels 27
# number of data 3282
# length of testing 820
# length of training 2462
# start training...
# number of correct predction:793
# accuracy 0.9670731707317073
