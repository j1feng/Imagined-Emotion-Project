# %%
#!pip install --user pandas
#!pip install --user numpy

import csv
import pandas as pd
import numpy as np

'''
with open('rec1.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    fields = next(reader)
    rows = []
    for row in reader:
        rows.append(row)
    print("Total no. of rows: %d"%(reader.line_num))

# printing the field names 
print('Field names are:' + ', '.join(field for field in fields)) 
  
#  printing first 5 rows 
print('\nFirst 5 rows are:\n') 
for row in rows[:5]: 
    # parsing each column of a row 
    for col in row: 
        print("%10s"%col), 
    print('\n')
'''

import pandas
df = pandas.read_csv('rec1.csv')
print(df.head())

data = [[]]
label = []

for index, row in df.iterrows():
    label.append(int(row['Status']))
    data.append([row['1A1'], row['1A16'], row['1A19'],row['1A21'],row['1A24'],row['1A3'],row['1A6'],row['1A7'],row['1B15'],row['1B18'],
               row['1B21'],row['1B23'],row['1B26'],row['1B30'],row['1B7'],row['1B9'],row['1C11'],row['1C13'],row['1C15'],row['1C18'],
               row['1C20'],row['1C23'],row['1C25'],row['1D12'],row['1D20'],row['1D24'],row['1D27'],row['1D30'],row['1D32'],row['1D5'],
               row['1D7'],row['1D9'],row['1EX3'],row['1EX5'],row['1F10'],row['1F14'],row['1F21'],row['1F23'],row['1F28'],row['1F3'],
               row['1F31'],row['1F7'],row['1G11'],row['1G13'],row['1G16'],row['1G23'],row['1G25'],row['1G30'],row['1G32'],row['1G8'],
               row['1H16'],row['1H19'],row['1H2'],row['1H6'],row['1H9']])

print(label)
data.remove([])
print(data[0])
print(len(data))

# partition
validation_data = data[:int(len(data)/8)]
testing_data = data[int(len(data)/8):int(len(data)/4)]
training_data = data[int(len(data)/4):]

print(len(validation_data))
print(len(testing_data))
print(len(training_data))
# Out:
#    Unnamed: 0           1A1          1A16         1A19         1A21  \
# 0           0 -18876.730746 -16806.859571 -3981.008270 -5758.473736
# 1           1 -18882.855735 -16812.609560 -3986.383260 -5766.004972
# 2           2 -18881.918237 -16813.140809 -3988.039507 -5766.161222
# 3           3 -18873.762002 -16804.172076 -3978.570775 -5756.411240
# 4           4 -18872.543254 -16803.297078 -3977.320777 -5753.411245
#
#           1A24           1A3          1A6          1A7         1B15  ...  \
# 0 -8187.469248 -16102.454623 -9622.435346 -3279.728316 -2822.197911  ...
# 1 -8196.875480 -16107.892113 -9630.841581 -3288.322050 -2816.041673  ...
# 2 -8198.156728 -16108.860861 -9633.029077 -3290.103297 -2812.572929  ...
# 3 -8187.687997 -16098.454630 -9624.247843 -3280.290815 -2813.291678  ...
# 4 -8185.156752 -16096.360884 -9618.935353 -3276.759571 -2813.072928  ...
#
#            1G25         1G30          1G32          1G8          1H16  \
# 0 -11296.776002  1341.513145  12178.149372 -9330.185886 -21384.132363
# 1 -11303.182240  1355.981869  12183.024363 -9336.529624 -21388.819855
# 2 -11303.807239  1389.169307  12218.430548 -9336.373375 -21389.913603
# 3 -11297.182252  1409.731769  12225.836784 -9326.373393 -21384.569863
# 4 -11295.994754  1390.325555  12207.649317 -9326.998392 -21382.007367
